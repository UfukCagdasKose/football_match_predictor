# %%
# Import necessary libraries
import pandas as pd
import requests
import time
import os
from dotenv import load_dotenv

# %%
# Authentication header required for requests to the football-data.org API
# Loading API key from environment variables

load_dotenv()
API_KEY = os.getenv("API_KEY")

headers = { "X-Auth-Token": API_KEY }

# %%
# See all available competitions (leagues) data  
url_competitions = "https://api.football-data.org/v4/competitions/"
r_competitions = requests.get(url_competitions, headers=headers)
data_competitions = r_competitions.json()

# data["competitions"] contains all leagues
competitions = data_competitions["competitions"]
df_competitions = pd.json_normalize(competitions)
leagues = df_competitions[["id", "name", "code", "type"]]
leagues

# We will collect match data for the following leagues
# Premier League (England)
# La Liga (Spain)
# Serie A (Italy)
# Bundesliga (Germany)
# Ligue 1 (France)
# Out:
#       id                           name code    type
# 0   2013  Campeonato Brasileiro Série A  BSA  LEAGUE
# 1   2016                   Championship  ELC  LEAGUE
# 2   2021                 Premier League   PL  LEAGUE
# 3   2001          UEFA Champions League   CL     CUP
# 4   2018          European Championship   EC     CUP
# 5   2015                        Ligue 1  FL1  LEAGUE
# 6   2002                     Bundesliga  BL1  LEAGUE
# 7   2019                        Serie A   SA  LEAGUE
# 8   2003                     Eredivisie  DED  LEAGUE
# 9   2017                  Primeira Liga  PPL  LEAGUE
# 10  2152              Copa Libertadores  CLI     CUP
# 11  2014               Primera Division   PD  LEAGUE
# 12  2000                 FIFA World Cup   WC     CUP

# %%
# Fetch team names and id's
url_teams = f"https://api.football-data.org/v4/competitions/2021/teams?season=2024"
response_teams = requests.get(url_teams, headers=headers)
data_teams = response_teams.json()
    
season_teams = data_teams["teams"]
df_teams = pd.json_normalize(season_teams)

df_teams = df_teams[["id", "name", "shortName", "tla", "crest"]]
df_teams
# Out:
#       id                        name       shortName  tla  \
# 0     57                  Arsenal FC         Arsenal  ARS
# 1     58              Aston Villa FC     Aston Villa  AVL
# 2     61                  Chelsea FC         Chelsea  CHE
# 3     62                  Everton FC         Everton  EVE
# 4     63                   Fulham FC          Fulham  FUL
# 5     64                Liverpool FC       Liverpool  LIV
# 6     65          Manchester City FC        Man City  MCI
# 7     66        Manchester United FC      Man United  MUN
# 8     67         Newcastle United FC       Newcastle  NEW
# 9     73        Tottenham Hotspur FC       Tottenham  TOT
# 10    76  Wolverhampton Wanderers FC   Wolverhampton  WOL
# 11   338           Leicester City FC  Leicester City  LEI
# 12   340              Southampton FC     Southampton  SOU
# 13   349             Ipswich Town FC    Ipswich Town  IPS
# 14   351        Nottingham Forest FC      Nottingham  NOT
# 15   354           Crystal Palace FC  Crystal Palace  CRY
# 16   397   Brighton & Hove Albion FC   Brighton Hove  BHA
# 17   402                Brentford FC       Brentford  BRE
# 18   563          West Ham United FC        West Ham  WHU
# 19  1044             AFC Bournemouth     Bournemouth  BOU
#
#                                                crest
# 0            https://crests.football-data.org/57.png
# 1            https://crests.football-data.org/58.png
# 2            https://crests.football-data.org/61.png
# 3            https://crests.football-data.org/62.png
# 4            https://crests.football-data.org/63.png
# 5            https://crests.football-data.org/64.png
# 6            https://crests.football-data.org/65.png
# 7            https://crests.football-data.org/66.png
# 8            https://crests.football-data.org/67.png
# 9            https://crests.football-data.org/73.png
# 10           https://crests.football-data.org/76.png
# 11          https://crests.football-data.org/338.png
# 12          https://crests.football-data.org/340.png
# 13          https://crests.football-data.org/349.png
# 14          https://crests.football-data.org/351.png
# 15          https://crests.football-data.org/354.png
# 16          https://crests.football-data.org/397.png
# 17          https://crests.football-data.org/402.png
# 18          https://crests.football-data.org/563.png
# 19  https://crests.football-data.org/bournemouth.png

# %% [markdown]
# ## Fetching Data

# %%
years = [2024,2023] # Last two seasons
league_ids = [2021,2019,2002,2015,2014] # League IDs
all_matches = [] # List to hold all match data

# This function retrieves all teams in a league for a specific season
# Then, for each team, it retrieves all matches played in that season
def get_teams_and_matches(league_id, year):
    
    # Fetch team names and id's
    url_teams = f"https://api.football-data.org/v4/competitions/{league_id}/teams?season={year}"
    response_teams = requests.get(url_teams, headers=headers)
    data_teams = response_teams.json()
    
    season_teams = data_teams["teams"]
    df_teams = pd.json_normalize(season_teams)

    # Retrieves all matches played in season and put into a list
    for team_id, team_shortname in zip(df_teams["id"], df_teams["shortName"]):
        url_matches = f"https://api.football-data.org/v4/teams/{team_id}/matches?season={year}&competitions={league_id}"
        response_matches = requests.get(url_matches, headers=headers)
        data_matches = response_matches.json()

        # Check if matches data is available 
        if "matches" in data_matches:
            df_team_matches = pd.json_normalize(data_matches["matches"])
            df_team_matches["team"] = team_shortname
            df_team_matches["opponent"] = df_team_matches.apply(lambda row: row["awayTeam.shortName"] if row["homeTeam.shortName"] == team_shortname else row["homeTeam.shortName"], axis=1)
            df_team_matches["team_is_home"] = df_team_matches.apply(lambda row: 1 if row["homeTeam.shortName"] == team_shortname else 0, axis=1)
            df_team_matches["result"] = df_team_matches.apply(lambda row: 1 if (row["score.winner"] == "HOME_TEAM" and row["team_is_home"] == 1) or
                                         (row["score.winner"] == "AWAY_TEAM" and row["team_is_home"] == 0) else 
                                         (2 if row["score.winner"] == "DRAW" else 0), axis=1)
            df_team_matches[["gf", "ga"]] = df_team_matches.apply(lambda row: pd.Series([row["score.fullTime.home"], row["score.fullTime.away"]]) if row["team_is_home"] == 1 
                                   else pd.Series([row["score.fullTime.away"], row["score.fullTime.home"]]), axis=1)
            all_matches.append(df_team_matches)

        time.sleep(9) # avoid hitting API rate limits


# Loop through each league and year to collect match data
#for league in league_ids:
    #for year in years:
        #get_teams_and_matches(league, year)
get_teams_and_matches(2021, 2025)
# Concatenate all match data into a single DataFrame
df_all_matches = pd.concat(all_matches, ignore_index=True)

# %% [markdown]
# ## Data cleaning and transformation

# %%
df_all_matches.columns
# Out:
# Index(['id', 'utcDate', 'status', 'matchday', 'stage', 'group', 'lastUpdated',
#        'referees', 'area.id', 'area.name', 'area.code', 'area.flag',
#        'competition.id', 'competition.name', 'competition.code',
#        'competition.type', 'competition.emblem', 'season.id',
#        'season.startDate', 'season.endDate', 'season.currentMatchday',
#        'season.winner', 'homeTeam.id', 'homeTeam.name', 'homeTeam.shortName',
#        'homeTeam.tla', 'homeTeam.crest', 'awayTeam.id', 'awayTeam.name',
#        'awayTeam.shortName', 'awayTeam.tla', 'awayTeam.crest', 'score.winner',
#        'score.duration', 'score.fullTime.home', 'score.fullTime.away',
#        'score.halfTime.home', 'score.halfTime.away', 'odds.msg'],
#       dtype='object')

# %%
# Select relevant columns for analysis
df = df_all_matches[[
        #'id',
        'utcDate', 
        'status', 
        'matchday',
        #'stage', 'group', 'lastUpdated',
        #'referees', 'area.id', 'area.name', 'area.code', 'area.flag',
        #'competition.id', 'competition.code', 
        'competition.name',
        #'competition.type', 'competition.emblem', 
        'season.id',
        #'season.startDate', 'season.endDate', 
        #'season.currentMatchday',
        #'season.winner', 
        'homeTeam.id', 
        #'homeTeam.name', 
        'homeTeam.shortName',
        #'homeTeam.tla', 
        #'homeTeam.crest', 
        'awayTeam.id', 
        #'awayTeam.name',
        'awayTeam.shortName', 
        #'awayTeam.tla', 
        #'awayTeam.crest',
        'score.winner',
        #'score.duration', 
        'score.fullTime.home', 'score.fullTime.away',
        #'score.halfTime.home', 'score.halfTime.away', 'odds.msg'
    ]]

# %%
# Copy the dataframe to avoid SettingWithCopyWarning
df = df.copy()
df = df[df["status"] == "FINISHED"]
df.head(20)
# Out:
#                   utcDate    status  matchday competition.name  season.id  \
# 0    2025-08-17T15:30:00Z  FINISHED         1   Premier League       2403
# 1    2025-08-23T16:30:00Z  FINISHED         2   Premier League       2403
# 38   2025-08-16T11:30:00Z  FINISHED         1   Premier League       2403
# 39   2025-08-23T14:00:00Z  FINISHED         2   Premier League       2403
# 76   2025-08-17T13:00:00Z  FINISHED         1   Premier League       2403
# 77   2025-08-22T19:00:00Z  FINISHED         2   Premier League       2403
# 114  2025-08-18T19:00:00Z  FINISHED         1   Premier League       2403
# 115  2025-08-24T13:00:00Z  FINISHED         2   Premier League       2403
# 152  2025-08-16T14:00:00Z  FINISHED         1   Premier League       2403
# 153  2025-08-24T15:30:00Z  FINISHED         2   Premier League       2403
# 190  2025-08-15T19:00:00Z  FINISHED         1   Premier League       2403
# 191  2025-08-25T19:00:00Z  FINISHED         2   Premier League       2403
# 228  2025-08-16T16:30:00Z  FINISHED         1   Premier League       2403
# 229  2025-08-23T11:30:00Z  FINISHED         2   Premier League       2403
# 266  2025-08-17T15:30:00Z  FINISHED         1   Premier League       2403
# 267  2025-08-24T15:30:00Z  FINISHED         2   Premier League       2403
# 304  2025-08-16T11:30:00Z  FINISHED         1   Premier League       2403
# 305  2025-08-25T19:00:00Z  FINISHED         2   Premier League       2403
# 342  2025-08-16T14:00:00Z  FINISHED         1   Premier League       2403
# 343  2025-08-23T14:00:00Z  FINISHED         2   Premier League       2403
#
#      homeTeam.id homeTeam.shortName  awayTeam.id awayTeam.shortName  \
# 0             66         Man United           57            Arsenal
# 1             57            Arsenal          341       Leeds United
# 38            58        Aston Villa           67          Newcastle
# 39           402          Brentford           58        Aston Villa
# 76            61            Chelsea          354     Crystal Palace
# 77           563           West Ham           61            Chelsea
# 114          341       Leeds United           62            Everton
# 115           62            Everton          397      Brighton Hove
# 152          397      Brighton Hove           63             Fulham
# 153           63             Fulham           66         Man United
# 190           64          Liverpool         1044        Bournemouth
# 191           67          Newcastle           64          Liverpool
# 228           76      Wolverhampton           65           Man City
# 229           65           Man City           73          Tottenham
# 266           66         Man United           57            Arsenal
# 267           63             Fulham           66         Man United
# 304           58        Aston Villa           67          Newcastle
# 305           67          Newcastle           64          Liverpool
# 342           71         Sunderland          563           West Ham
# 343          328            Burnley           71         Sunderland
#
#     score.winner  score.fullTime.home  score.fullTime.away
# 0      AWAY_TEAM                  0.0                  1.0
# 1      HOME_TEAM                  5.0                  0.0
# 38          DRAW                  0.0                  0.0
# 39     HOME_TEAM                  1.0                  0.0
# 76          DRAW                  0.0                  0.0
# 77     AWAY_TEAM                  1.0                  5.0
# 114    HOME_TEAM                  1.0                  0.0
# 115    HOME_TEAM                  2.0                  0.0
# 152         DRAW                  1.0                  1.0
# 153         DRAW                  1.0                  1.0
# 190    HOME_TEAM                  4.0                  2.0
# 191    AWAY_TEAM                  2.0                  3.0
# 228    AWAY_TEAM                  0.0                  4.0
# 229    AWAY_TEAM                  0.0                  2.0
# 266    AWAY_TEAM                  0.0                  1.0
# 267         DRAW                  1.0                  1.0
# 304         DRAW                  0.0                  0.0
# 305    AWAY_TEAM                  2.0                  3.0
# 342    HOME_TEAM                  3.0                  0.0
# 343    HOME_TEAM                  2.0                  0.0

# %%
# Rename columns for better readability
df = df.rename(columns={"utcDate":"date", "matchday":"week", "competition.name":"league",
                   "homeTeam.id":"home_id", "homeTeam.shortName":"home_name",
                   "awayTeam.id":"away_id", "awayTeam.shortName":"away_name",
                   "score.winner":"winner", "score.fullTime.home":"home_goals", "score.fullTime.away":"away_goals"})

# %%
# Standardize league and team names
df["league"] = df["league"].replace("Primera Division", "LaLiga")
df["home_name"] = df["home_name"].replace("Barça", "Barcelona")
df["away_name"] = df["away_name"].replace("Barça", "Barcelona")

# %%
# Convert date column to datetime and create separate columns for date and hour
df["date"] = pd.to_datetime(df["date"])
df["match_date"] = df["date"].dt.date
df["match_hour"] = df["date"].dt.hour  # this leaves only hours

df = df.drop(columns=["date"])

# %%
# Reorder the columns
cols = df.columns.tolist()
cols.remove("match_date")
cols.remove("match_hour")
new_order = [cols[0], "match_date", "match_hour"] + cols[1:]

# Reorder the dataframe
df = df[new_order]

# %%
df.head()
# Out:
#    match_week  match_date  match_hour          league  home_id    home_name  \
# 0           1  2024-08-17          14  Premier League       57      Arsenal
# 1           2  2024-08-24          16  Premier League       58  Aston Villa
# 2           3  2024-08-31          11  Premier League       57      Arsenal
# 3           4  2024-09-15          13  Premier League       73    Tottenham
# 4           5  2024-09-22          15  Premier League       65     Man City
#
#    away_id      away_name     winner  home_goals  away_goals
# 0       76  Wolverhampton  HOME_TEAM           2           0
# 1       57        Arsenal  AWAY_TEAM           0           2
# 2      397  Brighton Hove       DRAW           1           1
# 3       57        Arsenal  AWAY_TEAM           0           1
# 4       57        Arsenal       DRAW           2           2

# %%
# Save the DataFrame as CSV for the predictor
df.to_csv("top5_leagues_matches.csv")
